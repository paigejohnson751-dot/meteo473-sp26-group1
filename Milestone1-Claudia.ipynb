# %% [markdown]
# # Milestone 1 - Skiing Conditions and Comfort
# Claudia, Paige, Paula
#
#
# ### What are you thinking of focusing on?
# We are focusing on skiing conditions in the Northeast from December to March, looking at variables like snow depth, wind, temperature, and sky cover.
#
# ### What makes this hazard or application interesting to explore?
# Skiing conditions depend on a lot of interacting weather variables, and even small changes can have a big impact on comfort and safety espessially in the Northeast.
#
# ### Why might it be useful to quantify threat or impact in this area?
# This is useful because it could help people better understand when conditions are good, poor, or hazardous when planning to ski.
#
#
#
#
#
#
# Our project will focus on northeast skiing conditions for the months December - March. Taking into account of the varibles snow depth, wind, temperature, sky cover.
# (possibly total precip, categorical snow (precip type at every hour)(to make sure its snow), categorial rain)

# %%
import xarray as xr

# %%
ds = xr.open_dataset('gfs_2026022200.nc')
# Out:
# sh: 1: getfattr: not found

# %%
ds
# Out:
# <xarray.Dataset> Size: 9MB
# Dimensions:            (valid_time: 40, latitude: 81, longitude: 121)
# Coordinates:
#   * valid_time         (valid_time) datetime64[ns] 320B 2026-02-22 ... 2026-0...
#   * latitude           (latitude) float64 648B 55.0 54.75 54.5 ... 35.25 35.0
#   * longitude          (longitude) float64 968B 250.0 250.2 ... 279.8 280.0
#     time               datetime64[ns] 8B ...
#     step               (valid_time) timedelta64[ns] 320B ...
#     surface            float64 8B ...
#     heightAboveGround  float64 8B ...
#     atmosphere         float64 8B ...
# Data variables:
#     sde                (valid_time, latitude, longitude) float32 2MB ...
#     t2m                (valid_time, latitude, longitude) float32 2MB ...
#     tp                 (valid_time, latitude, longitude) float32 2MB ...
#     tcc                (valid_time, latitude, longitude) float32 2MB ...
#     u10                (valid_time, latitude, longitude) float32 2MB ...
# ...

# %%
ds.isel(valid_time = 30)
# Out:
# <xarray.Dataset> Size: 237kB
# Dimensions:            (latitude: 81, longitude: 121)
# Coordinates:
#   * latitude           (latitude) float64 648B 55.0 54.75 54.5 ... 35.25 35.0
#   * longitude          (longitude) float64 968B 250.0 250.2 ... 279.8 280.0
#     valid_time         datetime64[ns] 8B 2026-03-01T12:00:00
#     time               datetime64[ns] 8B ...
#     step               timedelta64[ns] 8B ...
#     surface            float64 8B ...
#     heightAboveGround  float64 8B ...
#     atmosphere         float64 8B ...
# Data variables:
#     sde                (latitude, longitude) float32 39kB ...
#     t2m                (latitude, longitude) float32 39kB ...
#     tp                 (latitude, longitude) float32 39kB ...
#     tcc                (latitude, longitude) float32 39kB ...
#     u10                (latitude, longitude) float32 39kB ...
#     v10                (latitude, longitude) float32 39kB ...
# Attributes:
#     GRIB_edition:            2
# ...

# %%
colors = [
    '#ffffff',
    '#f2f2f2',
    '#e6e6e6',
    '#d9d9d9',
    '#cccccc',
    '#bfbfbf',
    '#b3b3b3',
    '#a6a6a6',
    '#999999',
    '#8c8c8c',
    '#808080'
]

# %%
wind_mph = wind * 2.237
wind_chill = 35.74 + 0.6215 * t2m_f - 35.75 * (wind_mph ** 0.16) + 0.4275 * t2m_f * (wind_mph ** 0.16)

fig, ax1 = basemap()
plot1 = ax1.pcolormesh(lon, lat, wind_chill, cmap='coolwarm', transform=ccrs.PlateCarree(), vmin=-20, vmax=40)

from mpl_toolkits.axes_grid1.inset_locator import inset_axes

axins1 = inset_axes(ax1, width="100%", height="3%", loc='lower left', bbox_to_anchor=(0, -.05, 1, 1), bbox_transform=ax1.transAxes, borderpad=0)
fig.colorbar(plot1, cax=axins1, orientation='horizontal', label='°F')
ax1.set_title('Apparent Temperature (Wind Chill)', fontsize=14)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 u = ds_ne['u10']
#       2 v = ds_ne['v10']
#       3 wind = np.sqrt(u**2 + v**2)
#
# NameError: name 'ds_ne' is not defined
