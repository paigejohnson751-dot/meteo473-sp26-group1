# %% [markdown]
# # Milestone 1
# ## SKI
# ### Claudia, Paige, Paula
#
#
#
# Write your preliminary thoughts in a markdown cell in your notebook.
# ○ What are you thinking of focusing on?
# ○ What makes this hazard or application interesting to explore?
# ○ Why might it be useful to quantify threat or impact in this area?
#
#
# snow depth, wind, temp, sky cover
#
# total precip, categorical snow (precip type at every hour)(to make sure its snow), categorial rain.

# %%
from herbie import Herbie, FastHerbie
import pandas as pd, numpy as np
import xarray as xr
import dask

# %%
rain_levels = [0.01, 0.15, 0.25, 0.5, 1, 1.5, 2, 4, 6, 10, 13, 16, 20, 24]
#making my own color map for precip values
rain_colors = [
    '#ffffff',  
    '#c1e9c1',  
    '#a3d285', 
    '#62c278',  
    '#40b6dd',  
    '#2a90c7',  
    '#2050b5',  
    '#684997',  
    '#8c3494',  
    '#c71585', 
    '#dd00dd',  
    '#ff7d00',  
    '#ffd343' 
]
#setting up my colors to use for color bar
rain_cmap = mcolors.ListedColormap(rain_colors)
rain_norm = mcolors.BoundaryNorm(rain_levels, len(rain_colors))

# %% [markdown]
# ![image.png](attachment:93479e26-49e8-4c60-a6da-77b2db57f38f.png)![image.png](attachment:4778e6b2-cca1-4d8f-9ad3-a4f447645019.png)
# This NOAA satellite image shows the extratropical cyclone that caused the blizzard in the northeast which resulted in record snowfalls for many northeastern ski resorts.
